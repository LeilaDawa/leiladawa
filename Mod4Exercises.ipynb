# %% [markdown]
# # Module 4 Exercises - Data Visualization

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load the "dvddata.xlsx" file as a dataframe. Then rename the following columns (new column name is in parentheses):
# - \# of Clients (Clients)
# - Visits to each Client per Month (Visits)
# - Calls to each Client per month (Calls)
# - Emails to each Client per month (Emails)
# - \# of businesses in district (Business)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
location='datasets/dvddata.xlsx'
dvddata_df= pd.read_excel(location)

# %%
dvddata_df.columns
# Out:
# Index(['Salesperson', 'District', 'Region', 'Sales', '# of Clients',
#        ' Visits to each Client per Month', 'Calls to each Client per month',
#        'Emails to each Client per month', '# of businesses in district'],
#       dtype='object')

# %%
dvddata.rename(columns={'# of Clients': 'Clients', 'Visits to each Client per Month':'Visits','Calls to each Client per month':'Calls',
'Emails to each Client per month': 'Emails','# of businesses in district': 'Business'}, inplace =True)

# %%
dvddata.head()
# Out:
#        Salesperson  District Region  Sales  Clients  \
# 0     Addie Miller        52      A    393       16
# 1     Addie Miller        67      A    267       11
# 2     Addie Miller       104      A    148        4
# 3  Alexandra Jones        49      A    317       17
# 4   Alonzo Tennant        46      A    276       16
#
#     Visits to each Client per Month  Calls  Emails  Business
# 0                                 2      4      30       500
# 1                                 2      1      14       627
# 2                                 1      1      17       778
# 3                                 0      7       1       530
# 4                                 2      2      22       770

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe from the previous exercise, use the Seaborn library to create a scatterplot of the number of clients compared to the sales.

# %%
sns.lmplot(x='Clients', y='Sales', data=dvddata)

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe in the previous exercise, use the Seaborn library to make a boxplot of the Clients, Visits, Calls, and Emails columns. (**Hint**: Make a dataframe that only contains those columns)

# %%
dv1=dvddata.drop ('District', axis=1)
dv2=dv1.drop ('Sales', axis=1)
dv3=dv2.drop ('Business', axis=1)
dv3
# Out:
#             Salesperson Region  Clients   Visits to each Client per Month  \
# 0          Addie Miller      A       16                                 2
# 1          Addie Miller      A       11                                 2
# 2          Addie Miller      A        4                                 1
# 3       Alexandra Jones      A       17                                 0
# 4        Alonzo Tennant      A       16                                 2
# 5        Alonzo Tennant      A       16                                 2
# 6        Alonzo Tennant      A       11                                 1
# 7         Andrea Kraatz      A       13                                 2
# 8         Ann Dominguez      A        4                                 2
# 9            Anna Desai      A        4                                 2
# 10        Barbara Wales      A       19                                 2
# 11        Barbara Wales      A       10                                 1
# 12         Bessie Lewis      A       13                                 2
# 13         Bessie Lukas      A       13                                 1
# 14       Bessie Mcmanus      A       15                                 2
# 15       Bessie Mcmanus      A        7                                 2
# 16       Bessie Mcmanus      A       22                                 0
# 17        Caroline Boyd      A       20                                 0
# 18    Charlotte Simmons      A       17                                 0
# 19    Charlotte Simmons      A       22                                 0
# 20       Charmain Crisp      A       21                                 2
# 21      Christine Lopez      A        2                                 0
# 22  Christopher Alvardo      A        8                                 1
# 23  Christopher Alvardo      A        5                                 2
# 24      Connie Douglass      B       12                                 2
# 25      Cynthia Conklin      B       22                                 0
# 26      Cynthia Conklin      B       10                                 2
# 27      Cynthia Ellison      B       16                                 0
# 28        Deborah Seals      B        9                                 1
# 29        Deborah Seals      B       21                                 1
# ..                  ...    ...      ...                               ...
# 70           Lorna Kyle      C        4                                 1
# 71      Margaret Cooper      C       10                                 0
# 72      Margie Thrasher      C       21                                 1
# 73      Marilyn Sandler      C       11                                 2
# 74        Marisol Rosen      C        9                                 2
# 75        Martha Fabian      D       11                                 1
# 76         Mary Adamson      D       19                                 0
# 77        Mary Gauthier      D       12                                 0
# 78           Mary Smith      D        2                                 1
# 79          Megan Gault      D       14                                 1
# 80         Moses Chavez      D       10                                 1
# 81          Myrna Ellis      D       18                                 2
# 82         Nina Kennedy      D       16                                 2
# 83       Pamala Darrell      D       21                                 1
# 84      Rachel Griffith      D       18                                 0
# 85        Robert Liston      D        4                                 1
# 86        Ruby Meyerson      D        5                                 0
# 87       Sally Vineyard      D       20                                 1
# 88        Samuel Cuyler      D       19                                 1
# 89          Sarah Ellis      D       20                                 0
# 90           Sarah Hall      D        6                                 2
# 91     Sherry Davenport      D       15                                 2
# 92         Shirley Vick      D       22                                 1
# 93       Sonia Greenman      D       22                                 0
# 94        Susan J. Ward      D       11                                 2
# 95        Tammy Stowers      D       15                                 0
# 96         Terri Taylor      D       11                                 2
# 97         Terry Bonner      D        8                                 2
# 98        Terry Donnell      D       22                                 1
# 99        Trudy Vaughan      D       22                                 1
#
#     Calls  Emails
# 0       4      30
# 1       1      14
# 2       1      17
# 3       7       1
# 4       2      22
# 5       8      21
# 6       1       3
# 7       6      11
# 8       5      29
# 9       6      26
# 10      1      25
# 11      0      10
# 12      0      26
# 13      4       5
# 14      0      11
# 15      7      26
# 16      2       3
# 17      7      23
# 18      6      10
# 19      6      18
# 20      3      30
# 21      5       3
# 22      0      20
# 23      7      28
# 24      2       4
# 25      0      24
# 26      6      14
# 27      0       1
# 28      7       1
# 29      0      29
# ..    ...     ...
# 70      7      19
# 71      6       7
# 72      7      17
# 73      6      10
# 74      0       2
# 75      5      20
# 76      5      27
# 77      6      29
# 78      0      20
# 79      4       0
# 80      5      27
# 81      0      27
# 82      8       3
# 83      2      17
# 84      7      11
# 85      6       4
# 86      1      21
# 87      2      11
# 88      3      18
# 89      7      13
# 90      5      22
# 91      3      27
# 92      1      16
# 93      0       4
# 94      3      10
# 95      2      26
# 96      2       9
# 97      8      18
# 98      6      21
# 99      5      20
#
# [100 rows x 6 columns]

# %%
sns.boxplot(data=dv3)

# %% [markdown]
# ### Exercise 4:
#
# Using the dataframe from Exercise 3, use the Seaborn library to make a violin plot of sales per region.

# %%
plt.subplots(figsize=(13,7))
#violin plot shows the distribution of attack power for each type
sns.violinplot(x='Region', y='Sales', data=dvddata)

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe in the previous exercise, create a swarm plot of sales per region.

# %%
#swarm plot
plt.subplots(figsize=(10,6))
sns.swarmplot(x='Region', y='Sales', data=dvddata_df)

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a correlation heatmap.

# %%
corr = dvddata_df.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe in the previous exercise, make a bar chart (count plot) of the regions.

# %%
sns.countplot(x='Region',
              data=dvddata_df)

# %% [markdown]
# ### Bonus
#
# Feel free to explore any other data visualizations using the Seaborn library.
